# %% [markdown]
# <a href="https://colab.research.google.com/github/russell-ai/challenge-topic/blob/main/topic_modelling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup and imports

# %%
# !pip install bertopic
# Out:
# ...
#   Created wheel for hdbscan: filename=hdbscan-0.8.29-cp39-cp39-linux_x86_64.whl size=3582092 sha256=bf3d8e132bafed88c0e876ba9f94bae7cd330d9de599076d9052e34453348f89
#   Stored in directory: /root/.cache/pip/wheels/05/6f/88/1a4c04276b98306f00217a1e300e6ba0252c6aa4f7616067ae
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125942 sha256=4e8ce7393f2a73bf573b0ea64e49fc13c1187911a5827e8440de0a663201ec90
#   Stored in directory: /root/.cache/pip/wheels/71/67/06/162a3760c40d74dd40bc855d527008d26341c2b0ecf3e8e11f
# ...
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82830 sha256=6ae94d20f90e42f5281674b44ace19c46dbb3f1d4f5d69629f35d030e6112a4f
#   Stored in directory: /root/.cache/pip/wheels/f4/3e/1c/596d0a463d17475af648688443fa4846fef624d1390339e7e9
# ...
#   Created wheel for pynndescent: filename=pynndescent-0.5.8-py3-none-any.whl size=55509 sha256=0e663e904f629423bbe89f6a86ba824506b5f7521039f615c9a0d18005240ed0
# ...

# %% [markdown]
# # load data

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/sp500_cleaned.csv")
df.head()
# Out:
#   Symbol         name                                               text
# 0    MMM           3M  originally minnesota mining manufacturing comp...
# 1    AOS  A. O. Smith  smith corporation american manufacturer reside...
# 2    ABT       Abbott                                   abbott may refer
# 3   ABBV       AbbVie  abbvie inc american publicly traded pharmaceut...
# 4    ACN    Accenture  accenture plc irishamerican professional servi...

# %%
docs = df.text

# %%
from bertopic import BERTopic

# %%
topic_model = BERTopic(language="english", calculate_probabilities=False, verbose=True)
topics, probs = topic_model.fit_transform(docs)
# Out:
# ...
# Batches:   0%|          | 0/16 [00:00<?, ?it/s]
# 2023-03-16 18:20:03,601 - BERTopic - Transformed documents to Embeddings
# 2023-03-16 18:20:14,823 - BERTopic - Reduced dimensionality
# 2023-03-16 18:20:14,857 - BERTopic - Clustered reduced embeddings

# %%
freq = topic_model.get_topic_info(); freq.head(10)
# Out:
#    Topic  Count                              Name
# 0     -1     65  -1_company_stores_walmart_disney
# 1      0    181  0_company_products_new_announced
# 2      1     54  1_company_health_million_medical
# 3      2     43    2_bank_financial_banks_company
# 4      3     35     3_energy_power_tesla_electric
# 5      4     28         4_oil_company_gas_chevron
# 6      5     25   5_company_homes_acquired_estate
# 7      6     19   6_insurance_aig_metlife_company
# 8      7     16       7_carnival_mgm_hilton_hotel
# 9      8     14     8_netflix_tmobile_comcast_att

# %%
topic_model.get_topic(0)  # Select the most frequent topic
# Out:
# [('company', 0.029965734207821434),
#  ('products', 0.01644606327263819),
#  ('new', 0.014581336309762351),
#  ('announced', 0.014487843938216569),
#  ('also', 0.013678061057888482),
#  ('first', 0.013116916616657903),
#  ('business', 0.012183012395208128),
#  ('acquired', 0.012102197425073766),
#  ('million', 0.012095422379388444),
#  ('us', 0.011559142788801888)]

# %%
topic_model.topics_[:10]
# Out:
# [0, 0, 9, 1, -1, 8, 9, 0, 9, 0]

# %%
topic_model.visualize_topics(top_n_topics=10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
topic_model.visualize_barchart(top_n_topics=10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
topic_model.visualize_heatmap(top_n_topics=10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
topic_model.visualize_hierarchy(top_n_topics=10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
topic_model.visualize_term_rank()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
